# %% [markdown]
# # ETL Base de dados de Vendas
#
# 1. Carregar o arquivo vendas_5000_linhas e identificar o problema que existe em uma de suas colunas.
#
# 2. Conserte o erro da coluna identificada.
#
# 3. Produzir a coluna Total da Venda (preco * quantidade)
#
# 4. Produzir as colunas "Imposto Pago" e a coluna "Taxa de Pagamento"
#
# 5. **Regra coluna "Imposto Pago"**
#
#     - Acessórios -> 10% do total da venda
#     - Eletrônicos -> 7.5% do total da venda
#     - Móveis e Outros -> 5% do total da venda
#
# 6. **Regra coluna "Taxa de Pagamento":**
#
#     - Débito ou crédito -> 5% do total da venda
#     - Boleto -> 2.5% do total da venda
#     - Pix e outros -> 0% do total da venda
#
# 7. Produzir a coluna Lucro Total. (Soma da receitas - Soma das despesas)
#
# 8. Exportar dados resultantes para arquivo excel ou csv

# %% [markdown]
# # Carregamento e Diagnóstico

# %%
import pandas as pd

# %%
df = pd.read_csv("vendas_5000_linhas.csv")

display(df.head(10))
display(df.info())
display(df.dtypes)
display(df.columns)
display(df.duplicated().sum())
# Out:
#    data_venda      cliente         loja         produto    categoria  \
# 0  2023-04-15  Cliente 174   Loja Oeste           Mouse  Eletrônicos
# 1  2023-01-28  Cliente 144   Loja Norte        Notebook  Eletrônicos
# 2  2023-06-13  Cliente 179   Loja Leste         Monitor  Eletrônicos
# 3  2024-01-03   Cliente 89   Loja Oeste         Teclado  Eletrônicos
# 4  2024-07-19   Cliente 76   Loja Oeste         Celular  Eletrônicos
# 5  2023-08-27   Cliente 26   Loja Leste           Mouse  Eletrônicos
# 6  2024-12-19  Cliente 175  Loja Centro            Mesa       Móveis
# 7  2024-10-17  Cliente 177   Loja Oeste  Fone de Ouvido   Acessórios
# 8  2023-03-09   Cliente 55   Loja Oeste        Notebook  Eletrônicos
# 9  2024-07-28  Cliente 138     Loja Sul         Celular  Eletrônicos
#
#    quantidade  preco_unitario  custo_unitario          cidade estado  \
# 0           5          894.88          484.90       São Paulo     SP
# 1           2          804.30          524.09       São Paulo     SP
# 2          10         1009.76          768.22       Fortaleza     CE
# 3           6          402.63          247.21        Curitiba     PR
# 4           2         3407.25         2090.55        Brasília     DF
# 5           4         2717.09         2161.63       São Paulo     SP
# 6           6         1275.68          894.32  Belo Horizonte     MG
# 7           3         1644.80          955.60        Curitiba     PR
# 8           1         2827.41         1753.98        Curitiba     PR
# 9           8          542.91          294.20          Recife     PE
#
#          regiao forma_pagamento
# 0       sudeste          Boleto
# 1  centro-oeste          Boleto
# 2      Nordeste             Pix
# 3           SUL         Crédito
# 4      Nordeste          Débito
# 5           SUL          Boleto
# 6  CENTRO-OESTE          Débito
# 7           Sul             Pix
# 8      Nordeste          Débito
# 9  CENTRO-OESTE          Boleto
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   data_venda       5000 non-null   object
#  1   cliente          5000 non-null   object
#  2   loja             5000 non-null   object
#  3   produto          5000 non-null   object
#  4   categoria        5000 non-null   object
#  5   quantidade       5000 non-null   int64
#  6   preco_unitario   5000 non-null   float64
#  7   custo_unitario   5000 non-null   float64
#  8   cidade           5000 non-null   object
#  9   estado           5000 non-null   object
#  10  regiao           5000 non-null   object
#  11  forma_pagamento  5000 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 468.9+ KB
# None
# data_venda          object
# cliente             object
# loja                object
# produto             object
# categoria           object
# quantidade           int64
# preco_unitario     float64
# custo_unitario     float64
# cidade              object
# estado              object
# regiao              object
# forma_pagamento     object
# dtype: object
# Index(['data_venda', 'cliente', 'loja', 'produto', 'categoria', 'quantidade',
#        'preco_unitario', 'custo_unitario', 'cidade', 'estado', 'regiao',
#        'forma_pagamento'],
#       dtype='object')
# np.int64(0)

# %% [markdown]
# ## Correção de Tipos e Ajuste da Coluna Região

# %%
df[["cliente", "loja", "produto", "categoria", "cidade", "estado", "regiao", "forma_pagamento"]] = df[["cliente", "loja", "produto", "categoria", "cidade", "estado", "regiao", "forma_pagamento"]].astype("string")

df["data_venda"] = pd.to_datetime(df["data_venda"], errors="coerce")

df["regiao"] = df["regiao"].str.title()

# %% [markdown]
# ## Enriquecimento dos Dados

# %% [markdown]
# ### Coluna Total Venda

# %%
df["total_venda"] = df["preco_unitario"] * df["quantidade"]

# %% [markdown]
# ### Coluna Imposto Pago

# %%
# Método mais elegante
# def classificar_imposto(linha):
    
#     if linha["categoria"] == "Acessórios":
#         return linha["total_venda"] * 0.1
#     elif linha["categoria"] == "Eletrônicos":
#         return linha["total_venda"] * 0.075
#     else:
#         return linha["total_venda"] * 0.05

# df["imposto_pago"] = df.apply(classificar_imposto, axis=1).round(2)

# Método intermediário
def classificar_imposto(categoria):
    if categoria == "Acessórios":
        return 0.1
    elif categoria == "Eletrônicos":
        return 0.075
    else:
        return 0.05

df["imposto_porcentagem"] = df["categoria"].apply(classificar_imposto)
df["imposto_pago"] = df["total_venda"] * df["imposto_porcentagem"]
df["imposto_pago"] = df["imposto_pago"].round(2)


# Usando loc de maneira manual

# df["imposto_pago"] = df["total_venda"] * 0.05
# df.loc[df["categoria"] == "Acessório", "imposto_pago"] = df["total_venda"] * 0.1
# df.loc[df["categoria"] == "Eletrônicos", "imposto_pago"] = df["total_venda"] * 0.075

display(df.head(10))
# Out:
#   data_venda      cliente         loja         produto    categoria  \
# 0 2023-04-15  Cliente 174   Loja Oeste           Mouse  Eletrônicos
# 1 2023-01-28  Cliente 144   Loja Norte        Notebook  Eletrônicos
# 2 2023-06-13  Cliente 179   Loja Leste         Monitor  Eletrônicos
# 3 2024-01-03   Cliente 89   Loja Oeste         Teclado  Eletrônicos
# 4 2024-07-19   Cliente 76   Loja Oeste         Celular  Eletrônicos
# 5 2023-08-27   Cliente 26   Loja Leste           Mouse  Eletrônicos
# 6 2024-12-19  Cliente 175  Loja Centro            Mesa       Móveis
# 7 2024-10-17  Cliente 177   Loja Oeste  Fone de Ouvido   Acessórios
# 8 2023-03-09   Cliente 55   Loja Oeste        Notebook  Eletrônicos
# 9 2024-07-28  Cliente 138     Loja Sul         Celular  Eletrônicos
#
#    quantidade  preco_unitario  custo_unitario          cidade estado  \
# 0           5          894.88          484.90       São Paulo     SP
# 1           2          804.30          524.09       São Paulo     SP
# 2          10         1009.76          768.22       Fortaleza     CE
# 3           6          402.63          247.21        Curitiba     PR
# 4           2         3407.25         2090.55        Brasília     DF
# 5           4         2717.09         2161.63       São Paulo     SP
# 6           6         1275.68          894.32  Belo Horizonte     MG
# 7           3         1644.80          955.60        Curitiba     PR
# 8           1         2827.41         1753.98        Curitiba     PR
# 9           8          542.91          294.20          Recife     PE
#
#          regiao forma_pagamento  total_venda  imposto_porcentagem  \
# 0       Sudeste          Boleto      4474.40                0.075
# 1  Centro-Oeste          Boleto      1608.60                0.075
# 2      Nordeste             Pix     10097.60                0.075
# 3           Sul         Crédito      2415.78                0.075
# 4      Nordeste          Débito      6814.50                0.075
# 5           Sul          Boleto     10868.36                0.075
# 6  Centro-Oeste          Débito      7654.08                0.050
# 7           Sul             Pix      4934.40                0.100
# 8      Nordeste          Débito      2827.41                0.075
# 9  Centro-Oeste          Boleto      4343.28                0.075
#
#    imposto_pago
# 0        335.58
# 1        120.64
# 2        757.32
# 3        181.18
# 4        511.09
# 5        815.13
# 6        382.70
# 7        493.44
# 8        212.06
# 9        325.75

# %% [markdown]
# ### Coluna Taxa de Pagamento

# %%
def classificar_pagamento(forma_pagamento):
    if forma_pagamento == "Crédito" or forma_pagamento == "Débito":
        return 0.05
    elif forma_pagamento == "Boleto":
        return 0.025
    elif forma_pagamento == "Pix":
        return 0
    else:
        pd.NA


df["taxa_pagamento_porcentagem"] = df["forma_pagamento"].apply(classificar_pagamento)
df["taxa_pagamento_pago"] = df["total_venda"] * df["taxa_pagamento_porcentagem"]
df["taxa_pagamento_pago"] = df["taxa_pagamento_pago"].round(2)

# %% [markdown]
# ### Coluna Custo do Produto

# %%
df["custo_produtos"] = df["quantidade"] * df["custo_unitario"]

# %% [markdown]
# ### Coluna Custo da Venda

# %%
df["custo_venda"] = df["custo_produtos"] + df["imposto_pago"] + df["taxa_pagamento_pago"]

# %% [markdown]
# ### Coluna Lucro da Venda

# %%
df["lucro_venda"] = df["total_venda"] - df["custo_venda"]

# %% [markdown]
# # Exportação dos Dados

# %%
display(df.head(10))
display(df.info())
display(df[["total_venda", "imposto_pago", "taxa_pagamento_pago","custo_venda","lucro_venda"]].describe())

df.to_csv("vendas_5000_linhas_tratado.csv")
# Out:
#   data_venda      cliente         loja         produto    categoria  \
# 0 2023-04-15  Cliente 174   Loja Oeste           Mouse  Eletrônicos
# 1 2023-01-28  Cliente 144   Loja Norte        Notebook  Eletrônicos
# 2 2023-06-13  Cliente 179   Loja Leste         Monitor  Eletrônicos
# 3 2024-01-03   Cliente 89   Loja Oeste         Teclado  Eletrônicos
# 4 2024-07-19   Cliente 76   Loja Oeste         Celular  Eletrônicos
# 5 2023-08-27   Cliente 26   Loja Leste           Mouse  Eletrônicos
# 6 2024-12-19  Cliente 175  Loja Centro            Mesa       Móveis
# 7 2024-10-17  Cliente 177   Loja Oeste  Fone de Ouvido   Acessórios
# 8 2023-03-09   Cliente 55   Loja Oeste        Notebook  Eletrônicos
# 9 2024-07-28  Cliente 138     Loja Sul         Celular  Eletrônicos
#
#    quantidade  preco_unitario  custo_unitario          cidade estado  \
# 0           5          894.88          484.90       São Paulo     SP
# 1           2          804.30          524.09       São Paulo     SP
# 2          10         1009.76          768.22       Fortaleza     CE
# 3           6          402.63          247.21        Curitiba     PR
# 4           2         3407.25         2090.55        Brasília     DF
# 5           4         2717.09         2161.63       São Paulo     SP
# 6           6         1275.68          894.32  Belo Horizonte     MG
# 7           3         1644.80          955.60        Curitiba     PR
# 8           1         2827.41         1753.98        Curitiba     PR
# 9           8          542.91          294.20          Recife     PE
#
#          regiao forma_pagamento  total_venda  imposto_porcentagem  \
# 0       Sudeste          Boleto      4474.40                0.075
# 1  Centro-Oeste          Boleto      1608.60                0.075
# 2      Nordeste             Pix     10097.60                0.075
# 3           Sul         Crédito      2415.78                0.075
# 4      Nordeste          Débito      6814.50                0.075
# 5           Sul          Boleto     10868.36                0.075
# 6  Centro-Oeste          Débito      7654.08                0.050
# 7           Sul             Pix      4934.40                0.100
# 8      Nordeste          Débito      2827.41                0.075
# 9  Centro-Oeste          Boleto      4343.28                0.075
#
#    imposto_pago  taxa_pagamento_porcentagem  taxa_pagamento_pago  \
# 0        335.58                       0.025               111.86
# 1        120.64                       0.025                40.22
# 2        757.32                       0.000                 0.00
# 3        181.18                       0.050               120.79
# 4        511.09                       0.050               340.72
# 5        815.13                       0.025               271.71
# 6        382.70                       0.050               382.70
# 7        493.44                       0.000                 0.00
# 8        212.06                       0.050               141.37
# 9        325.75                       0.025               108.58
#
#    custo_produtos  custo_venda  lucro_venda
# 0         2424.50      2871.94      1602.46
# 1         1048.18      1209.04       399.56
# 2         7682.20      8439.52      1658.08
# 3         1483.26      1785.23       630.55
# 4         4181.10      5032.91      1781.59
# 5         8646.52      9733.36      1135.00
# 6         5365.92      6131.32      1522.76
# 7         2866.80      3360.24      1574.16
# 8         1753.98      2107.41       720.00
# 9         2353.60      2787.93      1555.35
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   data_venda                  5000 non-null   datetime64[ns]
#  1   cliente                     5000 non-null   string
#  2   loja                        5000 non-null   string
#  3   produto                     5000 non-null   string
#  4   categoria                   5000 non-null   string
#  5   quantidade                  5000 non-null   int64
#  6   preco_unitario              5000 non-null   float64
#  7   custo_unitario              5000 non-null   float64
#  8   cidade                      5000 non-null   string
#  9   estado                      5000 non-null   string
#  10  regiao                      5000 non-null   string
#  11  forma_pagamento             5000 non-null   string
#  12  total_venda                 5000 non-null   float64
#  13  imposto_porcentagem         5000 non-null   float64
#  14  imposto_pago                5000 non-null   float64
#  15  taxa_pagamento_porcentagem  5000 non-null   float64
#  16  taxa_pagamento_pago         5000 non-null   float64
#  17  custo_produtos              5000 non-null   float64
#  18  custo_venda                 5000 non-null   float64
#  19  lucro_venda                 5000 non-null   float64
# dtypes: datetime64[ns](1), float64(10), int64(1), string(8)
# memory usage: 781.4 KB
# None
#         total_venda  imposto_pago  taxa_pagamento_pago   custo_venda
# count   5000.000000   5000.000000          5000.000000   5000.000000
# mean    9683.523480    725.201164           301.631970   7309.604856
# std     8001.642637    629.658992           356.250763   6126.075979
# min       52.910000      2.650000             0.000000     40.640000
# 25%     3034.800000    221.642500            10.637500   2243.972500
# 50%     7371.515000    541.445000           167.000000   5599.900000
# 75%    14615.545000   1071.607500           466.565000  11097.530000
# max    34860.800000   3246.690000          1743.040000  31454.340000
